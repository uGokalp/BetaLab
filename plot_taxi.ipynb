# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
df = pd.read_csv('train_10train.csv')

# %%
df.head(50)
# Out:
#     Unnamed: 0  Unnamed: 0.1                            key  fare_amount  \
# 0            0             0   2009-09-26 10:00:00.00000061         17.3
# 1            1             1  2013-05-30 23:19:00.000000198          7.0
# 2            2             2  2009-04-12 18:57:00.000000121          4.1
# 3            3             3   2012-03-28 12:05:00.00000034          8.9
# 4            4             4    2013-06-22 23:27:47.0000002          9.5
# 5            5             5  2011-06-13 18:40:00.000000169          8.5
# 6            6             6    2012-10-21 10:09:07.0000001         79.5
# 7            7             7    2013-07-25 13:09:42.0000001         12.5
# 8            8             8   2013-11-16 13:36:00.00000049         17.5
# 9            9             9    2011-05-19 17:50:55.0000001         10.1
# 10          10            10  2010-06-20 15:15:00.000000127          5.3
# 11          11            11   2011-12-07 09:48:00.00000059          5.7
# 12          12            12    2012-07-20 19:46:56.0000002         34.5
# 13          13            13    2012-02-28 20:16:53.0000002         12.1
# 14          14            14    2012-04-09 05:54:32.0000001          5.7
# 15          15            15    2009-08-16 03:47:05.0000003          9.3
# 16          16            16    2010-11-30 12:17:55.0000001          6.9
# 17          17            17    2009-02-25 12:45:50.0000002          3.3
# 18          18            18    2015-03-25 20:54:57.0000002          5.5
# 19          19            19    2013-02-13 17:49:30.0000001         41.3
# 20          20            20    2009-11-29 00:30:28.0000003         10.5
# 21          21            21  2013-11-21 08:58:00.000000169          5.0
# 22          22            22  2014-04-29 21:32:00.000000107          4.5
# 23          23            23    2015-01-11 07:54:47.0000003         10.5
# 24          24            24   2009-12-11 13:07:00.00000056          9.7
# 25          25            25  2012-07-22 20:46:00.000000159          9.3
# 26          26            26    2012-03-27 18:22:03.0000002          6.9
# 27          27            27    2010-05-24 15:19:53.0000002          5.7
# 28          28            28  2012-09-18 07:33:00.000000190          5.0
# 29          29            29    2014-10-04 14:28:27.0000007          6.5
# 30          30            30   2010-04-11 08:12:00.00000020         10.5
# 31          31            31  2009-12-29 21:45:00.000000138         10.1
# 32          32            32    2009-05-15 21:52:57.0000003          4.5
# 33          33            33  2010-04-07 19:43:00.000000143         10.9
# 34          34            34   2012-07-11 23:34:00.00000037         10.1
# 35          35            35    2015-06-27 19:00:24.0000001         11.5
# 36          36            36  2012-05-24 22:24:00.000000174          7.3
# 37          37            37    2010-01-09 21:21:54.0000004          8.5
# 38          38            38   2010-03-10 14:27:00.00000096         10.9
# 39          39            39    2011-03-05 13:33:39.0000002          5.3
# 40          40            40    2015-01-18 20:42:18.0000003         12.5
# 41          41            41    2013-03-18 22:45:08.0000002          9.0
# 42          42            42   2014-10-25 21:24:00.00000022         11.5
# 43          43            43    2013-04-24 07:37:40.0000003          6.5
# 44          44            44    2014-11-11 15:09:29.0000001         11.0
# 45          45            45    2009-12-30 01:12:22.0000001         24.5
# 46          46            46    2011-06-05 18:44:24.0000003          3.7
# 47          47            47    2013-01-10 20:18:38.0000004         10.0
# 48          48            48   2009-11-06 07:22:00.00000041          5.3
# 49          49            49  2009-03-05 21:06:00.000000260         10.9
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0   2009-09-26 10:00:00 UTC        -73.992270        40.694707
# 1   2013-05-30 23:19:00 UTC        -73.974095        40.783962
# 2   2009-04-12 18:57:00 UTC        -73.987312        40.768525
# 3   2012-03-28 12:05:00 UTC        -74.005063        40.748015
# 4   2013-06-22 23:27:47 UTC        -73.978311        40.745573
# 5   2011-06-13 18:40:00 UTC        -73.982260        40.757050
# 6   2012-10-21 10:09:07 UTC        -73.986463        40.758596
# 7   2013-07-25 13:09:42 UTC        -73.983957        40.767091
# 8   2013-11-16 13:36:00 UTC        -73.983007        40.751532
# 9   2011-05-19 17:50:55 UTC        -73.951814        40.773871
# 10  2010-06-20 15:15:00 UTC        -73.994792        40.760632
# 11  2011-12-07 09:48:00 UTC        -73.982267        40.758747
# 12  2012-07-20 19:46:56 UTC        -73.776789        40.645104
# 13  2012-02-28 20:16:53 UTC        -73.977518        40.734149
# 14  2012-04-09 05:54:32 UTC        -73.982178        40.771095
# 15  2009-08-16 03:47:05 UTC        -74.005123        40.751346
# 16  2010-11-30 12:17:55 UTC        -73.970462        40.764279
# 17  2009-02-25 12:45:50 UTC        -74.004769        40.737499
# 18  2015-03-25 20:54:57 UTC        -73.992928        40.734821
# 19  2013-02-13 17:49:30 UTC        -73.989021        40.757917
# 20  2009-11-29 00:30:28 UTC        -73.981357        40.773465
# 21  2013-11-21 08:58:00 UTC        -73.961143        40.769262
# 22  2014-04-29 21:32:00 UTC        -73.951687        40.714457
# 23  2015-01-11 07:54:47 UTC        -73.995705        40.759235
# 24  2009-12-11 13:07:00 UTC        -73.968353        40.767792
# 25  2012-07-22 20:46:00 UTC        -74.004215        40.717372
# 26  2012-03-27 18:22:03 UTC        -73.990999        40.740078
# 27  2010-05-24 15:19:53 UTC        -73.954309        40.764220
# 28  2012-09-18 07:33:00 UTC        -73.985670        40.752775
# 29  2014-10-04 14:28:27 UTC        -73.979428        40.766117
# 30  2010-04-11 08:12:00 UTC          0.000000         0.000000
# 31  2009-12-29 21:45:00 UTC        -73.964857        40.761857
# 32  2009-05-15 21:52:57 UTC        -73.971412        40.757892
# 33  2010-04-07 19:43:00 UTC        -73.969555        40.760172
# 34  2012-07-11 23:34:00 UTC        -74.005185        40.720407
# 35  2015-06-27 19:00:24 UTC        -73.985054        40.756634
# 36  2012-05-24 22:24:00 UTC        -73.955972        40.772257
# 37  2010-01-09 21:21:54 UTC        -74.008976        40.747461
# 38  2010-03-10 14:27:00 UTC        -73.992643        40.748325
# 39  2011-03-05 13:33:39 UTC        -73.954189        40.787083
# 40  2015-01-18 20:42:18 UTC        -73.982826        40.763508
# 41  2013-03-18 22:45:08 UTC        -74.002108        40.740422
# 42  2014-10-25 21:24:00 UTC        -74.001083        40.731471
# 43  2013-04-24 07:37:40 UTC        -73.987736        40.765337
# 44  2014-11-11 15:09:29 UTC        -73.946973        40.771714
# 45  2009-12-30 01:12:22 UTC        -73.984078        40.759611
# 46  2011-06-05 18:44:24 UTC        -73.955730        40.772282
# 47  2013-01-10 20:18:38 UTC        -73.979658        40.783706
# 48  2009-11-06 07:22:00 UTC        -73.868875        40.790573
# 49  2009-03-05 21:06:00 UTC        -73.985140        40.719022
#
#     dropoff_longitude  dropoff_latitude  passenger_count  \
# 0          -73.978580         40.753823                6
# 1          -73.951655         40.771982                5
# 2          -73.989643         40.762507                1
# 3          -74.004713         40.725563                4
# 4          -73.989952         40.733327                3
# 5          -73.982902         40.742082                1
# 6          -74.177176         40.694829                1
# 7          -73.977486         40.753346                1
# 8          -74.014047         40.702537                1
# 9          -73.973881         40.760048                1
# 10         -73.980550         40.780088                2
# 11         -73.982267         40.758747                1
# 12         -73.916345         40.746691                1
# 13         -73.964264         40.773627                2
# 14         -73.983705         40.755477                1
# 15         -74.004449         40.717053                1
# 16         -73.979328         40.773339                2
# 17         -73.999300         40.741669                1
# 18         -73.999763         40.730900                1
# 19         -73.865728         40.770991                1
# 20         -73.951136         40.807658                2
# 21         -73.968425         40.765150                2
# 22         -73.941170         40.718492                1
# 23         -73.961159         40.761730                1
# 24         -73.970817         40.751802                1
# 25         -73.985553         40.754185                1
# 26         -74.009811         40.736029                1
# 27         -73.946868         40.774157                1
# 28         -73.985670         40.752775                1
# 29         -73.979888         40.754739                1
# 30           0.000000          0.000000                5
# 31         -73.964857         40.761857                3
# 32         -73.965813         40.756460                1
# 33         -73.997787         40.722830                1
# 34         -73.994748         40.760208                1
# 35         -73.984047         40.754944                3
# 36         -73.979747         40.765962                2
# 37         -73.987224         40.755873                4
# 38         -73.994355         40.717080                1
# 39         -73.950944         40.779233                1
# 40         -73.960289         40.797943                1
# 41         -73.982332         40.747594                1
# 42         -73.978591         40.746714                1
# 43         -73.994984         40.749987                1
# 44         -73.972753         40.749900                1
# 45         -73.870642         40.730009                1
# 46         -73.961639         40.767694                1
# 47         -73.948392         40.770576                1
# 48         -73.864658         40.791897                1
# 49         -73.980468         40.688795                1
#
#                                 hood_pick           drop_hood  boro_pick  \
# 0                        Brooklyn Heights             Midtown   Brooklyn
# 1                         Upper West Side     Upper East Side  Manhattan
# 2                          Hell's Kitchen      Hell's Kitchen  Manhattan
# 3                                 Chelsea                SoHo  Manhattan
# 4                                Kips Bay        East Village  Manhattan
# 5                                 Midtown             Midtown  Manhattan
# 6                        Theater District                 rip  Manhattan
# 7                          Hell's Kitchen             Midtown  Manhattan
# 8                                 Midtown  Financial District  Manhattan
# 9                         Upper East Side             Midtown  Manhattan
# 10                         Hell's Kitchen     Upper West Side  Manhattan
# 11                       Theater District    Theater District  Manhattan
# 12  John F. Kennedy International Airport           Sunnyside     Queens
# 13                        Stuyvesant Town     Upper East Side  Manhattan
# 14                        Upper West Side    Theater District  Manhattan
# 15                                Chelsea             Tribeca  Manhattan
# 16                        Upper East Side     Upper West Side  Manhattan
# 17                           West Village             Chelsea  Manhattan
# 18                      Greenwich Village   Greenwich Village  Manhattan
# 19                       Theater District   LaGuardia Airport  Manhattan
# 20                        Upper West Side              Harlem  Manhattan
# 21                        Upper East Side     Upper East Side  Manhattan
# 22                           Williamsburg        Williamsburg   Brooklyn
# 23                         Hell's Kitchen     Upper East Side  Manhattan
# 24                        Upper East Side             Midtown  Manhattan
# 25                                Tribeca    Theater District  Manhattan
# 26                      Flatiron District        West Village  Manhattan
# 27                        Upper East Side     Upper East Side  Manhattan
# 28                                Midtown             Midtown  Manhattan
# 29                                Midtown             Midtown  Manhattan
# 30                                    rip                 rip        rip
# 31                        Upper East Side     Upper East Side  Manhattan
# 32                                Midtown             Midtown  Manhattan
# 33                                Midtown                SoHo  Manhattan
# 34                                Tribeca      Hell's Kitchen  Manhattan
# 35                       Theater District    Theater District  Manhattan
# 36                        Upper East Side             Midtown  Manhattan
# 37                                Chelsea    Theater District  Manhattan
# 38                                Chelsea           Chinatown  Manhattan
# 39                        Upper East Side     Upper East Side  Manhattan
# 40                                Midtown     Upper West Side  Manhattan
# 41                                Chelsea         Murray Hill  Manhattan
# 42                      Greenwich Village         Murray Hill  Manhattan
# 43                         Hell's Kitchen             Chelsea  Manhattan
# 44                        Upper East Side         Murray Hill  Manhattan
# 45                       Theater District           Rego Park  Manhattan
# 46                        Upper East Side     Upper East Side  Manhattan
# 47                        Upper West Side     Upper East Side  Manhattan
# 48                                    rip                 rip        rip
# 49                        Lower East Side         Fort Greene  Manhattan
#
#     boro_drop
# 0   Manhattan
# 1   Manhattan
# 2   Manhattan
# 3   Manhattan
# 4   Manhattan
# 5   Manhattan
# 6         rip
# 7   Manhattan
# 8   Manhattan
# 9   Manhattan
# 10  Manhattan
# 11  Manhattan
# 12     Queens
# 13  Manhattan
# 14  Manhattan
# 15  Manhattan
# 16  Manhattan
# 17  Manhattan
# 18  Manhattan
# 19     Queens
# 20  Manhattan
# 21  Manhattan
# 22   Brooklyn
# 23  Manhattan
# 24  Manhattan
# 25  Manhattan
# 26  Manhattan
# 27  Manhattan
# 28  Manhattan
# 29  Manhattan
# 30        rip
# 31  Manhattan
# 32  Manhattan
# 33  Manhattan
# 34  Manhattan
# 35  Manhattan
# 36  Manhattan
# 37  Manhattan
# 38  Manhattan
# 39  Manhattan
# 40  Manhattan
# 41  Manhattan
# 42  Manhattan
# 43  Manhattan
# 44  Manhattan
# 45     Queens
# 46  Manhattan
# 47  Manhattan
# 48        rip
# 49   Brooklyn

# %%
# %timeit df["pickup_datetime"] = pd.to_datetime(df['pickup_datetime'],infer_datetime_format=True)
# Out:
# 953 µs ± 454 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df["day_of_week"] = df.pickup_datetime.dt.dayofweek
df["month"] = df.pickup_datetime.dt.month
df["month_name"] = df.pickup_datetime.dt.month_name()
df["hour"] = df.pickup_datetime.dt.hour

# %%
df["year"] = df.pickup_datetime.dt.year

# %%
df["dayname"] = df.pickup_datetime.dt.day_name()

# %%
df['times'] = ['day' if (x >= 5 and x <= 11) else 'afternoon' if (x > 11 and x <=17) else 'evening' if (x > 17 and x < 22) else 'night' if (x >= 22) else 'night' if (x >= 0 and x < 5) else 'error' for x in df['hour']]

# %%
sns.countplot("hood_pick", data=df,hue='times',hue_order=["day","afternoon","evening","night"],palette  = "GnBu_d",order = pd.value_counts(df['hood_pick']).iloc[:5].index)

# %%
g=sns.FacetGrid(data=df,col='times',col_order=["day","afternoon","evening","night"],aspect=2)
g.map(sns.countplot,"hood_pick",palette  = "GnBu_d",order = pd.value_counts(df['hood_pick']).iloc[:5].index)
plt.gcf().set_size_inches(25, 5)

# %%
g=sns.FacetGrid(data=df,col='times',col_order=["day","afternoon","evening","night"])
g.map(sns.countplot,"drop_hood",palette  = "GnBu_d",order = pd.value_counts(df['drop_hood']).iloc[:5].index)
plt.gcf().set_size_inches(25, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'hood_pick', 'drop_hood',
#        'boro_pick', 'boro_drop', 'day_of_week', 'month', 'month_name', 'hour',
#        'year', 'dayname', 'times'],
#       dtype='object')

# %%
df.groupby("times", as_index=True)[['hood_pick','boro_pick', 'drop_hood', 'boro_drop']].agg(lambda x: scipy.stats.mode(x))
# Out:
# /Users/mac/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:248: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
#                              hood_pick               boro_pick  \
# times
# afternoon          ([Midtown], [5344])  ([Manhattan], [26222])
# day        ([Upper East Side], [4266])  ([Manhattan], [22798])
# evening            ([Midtown], [4486])  ([Manhattan], [21722])
# night              ([Midtown], [3334])  ([Manhattan], [19831])
#
#                              drop_hood               boro_drop
# times
# afternoon          ([Midtown], [5206])  ([Manhattan], [25880])
# day                ([Midtown], [6160])  ([Manhattan], [22346])
# evening    ([Upper East Side], [3355])  ([Manhattan], [21240])
# night              ([Midtown], [2307])  ([Manhattan], [17664])

# %%
df.groupby("hour", as_index=True)[['hood_pick','boro_pick', 'drop_hood', 'boro_drop']].agg(lambda x: scipy.stats.mode(x))
# Out:
#                        hood_pick              boro_pick  \
# hour
# 0             ([Midtown], [555])  ([Manhattan], [3448])
# 1             ([Midtown], [389])  ([Manhattan], [2590])
# 2             ([Midtown], [260])  ([Manhattan], [1929])
# 3             ([Midtown], [190])  ([Manhattan], [1441])
# 4             ([Midtown], [139])  ([Manhattan], [1063])
# 5     ([Upper East Side], [126])   ([Manhattan], [835])
# 6     ([Upper East Side], [312])  ([Manhattan], [1831])
# 7     ([Upper East Side], [673])  ([Manhattan], [3175])
# 8     ([Upper East Side], [856])  ([Manhattan], [4122])
# 9             ([Midtown], [825])  ([Manhattan], [4359])
# 10            ([Midtown], [806])  ([Manhattan], [4156])
# 11            ([Midtown], [883])  ([Manhattan], [4320])
# 12           ([Midtown], [1027])  ([Manhattan], [4684])
# 13            ([Midtown], [970])  ([Manhattan], [4449])
# 14            ([Midtown], [949])  ([Manhattan], [4572])
# 15            ([Midtown], [850])  ([Manhattan], [4275])
# 16            ([Midtown], [699])  ([Manhattan], [3705])
# 17            ([Midtown], [849])  ([Manhattan], [4537])
# 18           ([Midtown], [1048])  ([Manhattan], [5343])
# 19           ([Midtown], [1168])  ([Manhattan], [5654])
# 20           ([Midtown], [1122])  ([Manhattan], [5388])
# 21           ([Midtown], [1148])  ([Manhattan], [5337])
# 22            ([Midtown], [972])  ([Manhattan], [4923])
# 23            ([Midtown], [829])  ([Manhattan], [4437])
#
#                        drop_hood              boro_drop
# hour
# 0             ([Midtown], [397])  ([Manhattan], [3078])
# 1             ([Midtown], [257])  ([Manhattan], [2248])
# 2     ([Upper East Side], [169])  ([Manhattan], [1626])
# 3             ([Midtown], [130])  ([Manhattan], [1178])
# 4              ([Midtown], [87])   ([Manhattan], [800])
# 5             ([Midtown], [135])   ([Manhattan], [654])
# 6             ([Midtown], [524])  ([Manhattan], [1701])
# 7            ([Midtown], [1014])  ([Manhattan], [3138])
# 8            ([Midtown], [1265])  ([Manhattan], [4129])
# 9            ([Midtown], [1209])  ([Manhattan], [4336])
# 10           ([Midtown], [1077])  ([Manhattan], [4143])
# 11            ([Midtown], [936])  ([Manhattan], [4245])
# 12           ([Midtown], [1009])  ([Manhattan], [4589])
# 13            ([Midtown], [906])  ([Manhattan], [4343])
# 14            ([Midtown], [938])  ([Manhattan], [4486])
# 15            ([Midtown], [844])  ([Manhattan], [4222])
# 16            ([Midtown], [707])  ([Manhattan], [3741])
# 17            ([Midtown], [802])  ([Manhattan], [4499])
# 18    ([Upper East Side], [869])  ([Manhattan], [5299])
# 19    ([Upper East Side], [894])  ([Manhattan], [5576])
# 20            ([Midtown], [814])  ([Manhattan], [5234])
# 21    ([Upper East Side], [779])  ([Manhattan], [5131])
# 22            ([Midtown], [697])  ([Manhattan], [4659])
# 23            ([Midtown], [572])  ([Manhattan], [4075])

# %%
df.groupby("times", as_index=True)['hood_pick','drop_hood'].apply(lambda x: (x =="LaGuardia Airport").sum())
# Out:
#            hood_pick  drop_hood
# times
# afternoon        696        513
# day              378        567
# evening          529         85
# night            317         66

# %%
df.groupby("times", as_index=True)['hood_pick','drop_hood'].apply(lambda x: (x =='John F. Kennedy International Airport').sum())
# Out:
#            hood_pick  drop_hood
# times
# afternoon        522        359
# day              305        271
# evening          393         92
# night            275         46

# %%
df.groupby("times", as_index=True)['hood_pick','drop_hood'].apply(lambda x: (x =="SoHo").sum())
# Out:
#            hood_pick  drop_hood
# times
# afternoon        705        657
# day              414        525
# evening          589        480
# night            627        422

# %%
df[df.drop_hood == "LaGuardia Airport"].iloc[0:50, 10:14].apply(lambda x: scipy.stats.mode(x))
# Out:
# hood_pick              ([Midtown], [10])
# drop_hood    ([LaGuardia Airport], [50])
# boro_pick            ([Manhattan], [44])
# boro_drop               ([Queens], [50])
# dtype: object

# %%
df[df.drop_hood == "John F. Kennedy International Airport"].iloc[0:50, 10:14].apply(lambda x: scipy.stats.mode(x))
# Out:
# hood_pick                           ([Upper East Side], [8])
# drop_hood    ([John F. Kennedy International Airport], [50])
# boro_pick                                ([Manhattan], [38])
# boro_drop                                   ([Queens], [50])
# dtype: object

# %%
df.iloc[:, 10:14].apply(lambda x: (x =="LaGuardia Airport").sum())
# Out:
# hood_pick    1920
# drop_hood    1231
# boro_pick       0
# boro_drop       0
# dtype: int64

# %%
df.iloc[0:, 10:14].apply(lambda x: (x =="John F. Kennedy International Airport").sum())
# Out:
# hood_pick    1495
# drop_hood     768
# boro_pick       0
# boro_drop       0
# dtype: int64

# %%
df.groupby("year", as_index=True)[['hood_pick','boro_pick', 'drop_hood', 'boro_drop']].agg(lambda x: scipy.stats.mode(x))
# Out:
#                 hood_pick               boro_pick            drop_hood  \
# year
# 2009  ([Midtown], [2726])  ([Manhattan], [14283])  ([Midtown], [2708])
# 2010  ([Midtown], [2580])  ([Manhattan], [13647])  ([Midtown], [2565])
# 2011  ([Midtown], [2774])  ([Manhattan], [14238])  ([Midtown], [2694])
# 2012  ([Midtown], [2793])  ([Manhattan], [14424])  ([Midtown], [2650])
# 2013  ([Midtown], [2634])  ([Manhattan], [14221])  ([Midtown], [2680])
# 2014  ([Midtown], [2577])  ([Manhattan], [13413])  ([Midtown], [2477])
# 2015  ([Midtown], [1125])   ([Manhattan], [6347])  ([Midtown], [1181])
#
#                    boro_drop
# year
# 2009  ([Manhattan], [13737])
# 2010  ([Manhattan], [13141])
# 2011  ([Manhattan], [13750])
# 2012  ([Manhattan], [13904])
# 2013  ([Manhattan], [13674])
# 2014  ([Manhattan], [12853])
# 2015   ([Manhattan], [6071])

# %%
listA = list(pd.value_counts(df['hood_pick']).iloc[0:9].index)
listA
# Out:
# ['Midtown',
#  'Upper East Side',
#  'Chelsea',
#  'Upper West Side',
#  "Hell's Kitchen",
#  'East Village',
#  'Theater District',
#  'West Village',
#  'Murray Hill']

# %%
df[df.hood_pick.isin(listA)].pivot_table(index='times',columns='hood_pick',values='key',aggfunc='count')
# Out:
# hood_pick  Chelsea  East Village  Hell's Kitchen  Midtown  Murray Hill  \
# times
# afternoon     2474           814            1313     5344          767
# day           2133           738            1386     4045          797
# evening       2160           902            1160     4486          627
# night         2034          1676            1271     3334          432
#
# hood_pick  Theater District  Upper East Side  Upper West Side  West Village
# times
# afternoon              1022             4709             2809           772
# day                     923             4266             2432           795
# evening                 950             3077             2105           869
# night                   917             1629             1296          1334

# %% [markdown]
# ### Percentage share of pickup borough

# %%
df[df.boro_pick.isin(["Bronx","Brooklyn","Manhattan","Queens"])].pivot_table(index='times',columns='boro_pick',values='key',aggfunc=len,margins=True).div(len(df.index)).mul(100).round(decimals=2)
# Out:
# boro_pick  Bronx  Brooklyn  Manhattan  Queens    All
# times
# afternoon   0.02      0.33      26.22    1.54  28.11
# day         0.02      0.40      22.80    1.13  24.34
# evening     0.01      0.44      21.72    1.13  23.30
# night       0.02      1.03      19.83    0.98  21.87
# All         0.07      2.19      90.57    4.79  97.62

# %%
pd.value_counts(df['hood_pick'])
# Out:
# Midtown                                  17209
# Upper East Side                          13681
# Chelsea                                   8801
# Upper West Side                           8642
# Hell's Kitchen                            5130
# East Village                              4130
# Theater District                          3812
# West Village                              3770
# Murray Hill                               2623
# rip                                       2370
# SoHo                                      2335
# Greenwich Village                         2283
# Gramercy                                  2202
# Kips Bay                                  2173
# LaGuardia Airport                         1920
# Tribeca                                   1786
# Financial District                        1748
# Lower East Side                           1614
# Flatiron District                         1598
# John F. Kennedy International Airport     1495
# Central Park                              1415
# East Harlem                                886
# Battery Park City                          831
# NoHo                                       808
# Morningside Heights                        658
# Williamsburg                               625
# Harlem                                     534
# Stuyvesant Town                            478
# Nolita                                     468
# Chinatown                                  407
#                                          ...
# Bergen Beach                                 1
# Bellerose                                    1
# South Beach                                  1
# Bayside                                      1
# Bath Beach                                   1
# Willowbrook                                  1
# Fordham                                      1
# Castle Hill                                  1
# Ellis Island                                 1
# Hunts Point                                  1
# Manhattan Beach                              1
# Great Kills Park                             1
# Allerton                                     1
# Melrose                                      1
# Clason Point                                 1
# University Heights                           1
# Woodhaven                                    1
# Forest Park                                  1
# Mount Hope                                   1
# Kingsbridge                                  1
# Douglaston                                   1
# Broad Channel                                1
# Shore Acres                                  1
# Co-op City                                   1
# Great Kills                                  1
# Bronx Park                                   1
# Riverdale                                    1
# Claremont Village                            1
# Van Nest                                     1
# Flatlands                                    1
# Name: hood_pick, Length: 153, dtype: int64

# %% [markdown]
# ### Percentage share of pickup neighbourhood

# %%
pd.value_counts(df['hood_pick']).apply(lambda x: x>1)
# Out:
# Midtown                                   True
# Upper East Side                           True
# Chelsea                                   True
# Upper West Side                           True
# Hell's Kitchen                            True
# East Village                              True
# Theater District                          True
# West Village                              True
# Murray Hill                               True
# rip                                       True
# SoHo                                      True
# Greenwich Village                         True
# Gramercy                                  True
# Kips Bay                                  True
# LaGuardia Airport                         True
# Tribeca                                   True
# Financial District                        True
# Lower East Side                           True
# Flatiron District                         True
# John F. Kennedy International Airport     True
# Central Park                              True
# East Harlem                               True
# Battery Park City                         True
# NoHo                                      True
# Morningside Heights                       True
# Williamsburg                              True
# Harlem                                    True
# Stuyvesant Town                           True
# Nolita                                    True
# Chinatown                                 True
#                                          ...
# Bergen Beach                             False
# Bellerose                                False
# South Beach                              False
# Bayside                                  False
# Bath Beach                               False
# Willowbrook                              False
# Fordham                                  False
# Castle Hill                              False
# Ellis Island                             False
# Hunts Point                              False
# Manhattan Beach                          False
# Great Kills Park                         False
# Allerton                                 False
# Melrose                                  False
# Clason Point                             False
# University Heights                       False
# Woodhaven                                False
# Forest Park                              False
# Mount Hope                               False
# Kingsbridge                              False
# Douglaston                               False
# Broad Channel                            False
# Shore Acres                              False
# Co-op City                               False
# Great Kills                              False
# Bronx Park                               False
# Riverdale                                False
# Claremont Village                        False
# Van Nest                                 False
# Flatlands                                False
# Name: hood_pick, Length: 153, dtype: bool

# %%
df[df.hood_pick.isin(listA)].pivot_table(index='times',columns='hood_pick',values='key',aggfunc=len,margins=True).div(len(df.index)).mul(100).round(decimals=2)
# Out:
# hood_pick  Chelsea  East Village  Hell's Kitchen  Midtown  Murray Hill  \
# times
# afternoon     2.47          0.81            1.31     5.34         0.77
# day           2.13          0.74            1.39     4.04         0.80
# evening       2.16          0.90            1.16     4.49         0.63
# night         2.03          1.68            1.27     3.33         0.43
# All           8.80          4.13            5.13    17.21         2.62
#
# hood_pick  Theater District  Upper East Side  Upper West Side  West Village  \
# times
# afternoon              1.02             4.71             2.81          0.77
# day                    0.92             4.27             2.43          0.80
# evening                0.95             3.08             2.10          0.87
# night                  0.92             1.63             1.30          1.33
# All                    3.81            13.68             8.64          3.77
#
# hood_pick    All
# times
# afternoon  20.02
# day        17.52
# evening    16.34
# night      13.92
# All        67.80

# %%
listA
# Out:
# ['Midtown',
#  'Upper East Side',
#  'Upper West Side',
#  'Chelsea',
#  "Hell's Kitchen",
#  'East Village',
#  'Theater District',
#  'West Village',
#  'Murray Hill']

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="hood_pick",order=(listA),hue='times',data=df[df.hood_pick.isin(listA)],palette  = "GnBu_d")

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="drop_hood",order=(listA),hue='times',data=df[df.hood_pick.isin(listA)],palette  = "GnBu_d")

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="boro_pick",order=(listB),hue='times',data=df[df.boro_pick.isin(listB)],palette  = "GnBu_d")

# %%
list(df.boro_drop.unique())
# Out:
# ['Manhattan', 'rip', 'Queens', 'Brooklyn', 'Bronx', 'Staten Island']

# %%
listB = ['Manhattan','Queens', 'Brooklyn', 'Bronx', 'Staten Island']

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="boro_drop",order=(listB),hue='times',data=df[df.boro_drop.isin(listB)],palette  = "GnBu_d")

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="boro_pick",order=(listB),hue='year',data=df[df.boro_pick.isin(listB)],palette  = "GnBu_d")

# %% [markdown]
# Where can we go from here?
#  * We can extend the data to include weather data to see if number of rides every hour is correlated with the weather data.
#  * We could also acquire data for major events going on every neighbourhood across time.
